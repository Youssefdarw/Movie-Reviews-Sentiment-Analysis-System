# %% [markdown]
# # Implementing an End-to-End Automated Machine Learning Pipeline

# %% [markdown]
# This project focuses on creating an automated machine learning application that addresses a specific problem statement. The application will feature a complete pipeline for data preprocessing, model training, evaluation, and deployment. Emphasizing MLOps practices, this project aims to automate ML workflows effectively.

# %% [markdown]
# # Load the Dataset

# %%
import pandas as pd
import os

def load_imdb_dataset(dataset_dir):
    data = {'review': [], 'sentiment': []}
    for label in ['pos', 'neg']:
        sentiment_dir = os.path.join(dataset_dir, label)
        for filename in os.listdir(sentiment_dir):
            if filename.endswith('.txt'):
                with open(os.path.join(sentiment_dir, filename), 'r', encoding='utf-8') as file:
                    review = file.read()
                    data['review'].append(review)
                    data['sentiment'].append(1 if label == 'pos' else 0)
    return pd.DataFrame(data)

train_df = load_imdb_dataset('train')
test_df = load_imdb_dataset('test')

# %% [markdown]
# # Preprocess the Text Data

# %%
# !pip install transformers
# !pip install torch
# Out:
# Requirement already satisfied: transformers in /Users/youssef/anaconda3/lib/python3.11/site-packages (4.32.1)
# Requirement already satisfied: filelock in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /Users/youssef/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: torch in /Users/youssef/anaconda3/lib/python3.11/site-packages (2.1.2)
# Requirement already satisfied: filelock in /Users/youssef/anaconda3/lib/python3.11/site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in /Users/youssef/anaconda3/lib/python3.11/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /Users/youssef/anaconda3/lib/python3.11/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /Users/youssef/anaconda3/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /Users/youssef/anaconda3/lib/python3.11/site-packages (from torch) (2023.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from sympy->torch) (1.3.0)

# %%
from transformers import BertTokenizer
from torch.utils.data import DataLoader, TensorDataset
import torch

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

def preprocess_data(df, tokenizer, max_length=128):
    input_ids = []
    attention_masks = []

    for review in df['review']:
        encoded = tokenizer.encode_plus(
            review,
            add_special_tokens=True,
            max_length=max_length,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
        )
        input_ids.append(encoded['input_ids'])
        attention_masks.append(encoded['attention_mask'])

    input_ids = torch.cat(input_ids, dim=0)
    attention_masks = torch.cat(attention_masks, dim=0)
    labels = torch.tensor(df['sentiment'].values)

    return TensorDataset(input_ids, attention_masks, labels)

train_dataset = preprocess_data(train_df, tokenizer)
test_dataset = preprocess_data(test_df, tokenizer)
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]

# %% [markdown]
# ## Text Cleaning and Normalization

# %%
import re
import pandas as pd
from nltk.corpus import stopwords

# Ensure stopwords are downloaded
import nltk
nltk.download('stopwords')

# Text cleaning function
def clean_text(text):
    text = text.lower()  # Lowercase text
    text = re.sub(r'<.*?>', '', text)  # Remove HTML tags
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)  # Remove URLs
    text = re.sub(r'\@w+|\#', '', text)  # Remove mentions and hashtags
    text = re.sub(r'[^A-Za-z0-9]+', ' ', text)  # Remove special characters
    text = ' '.join([word for word in text.split() if word not in stopwords.words('english')])  # Remove stopwords
    return text

# Apply cleaning to the dataset
train_df['clean_review'] = train_df['review'].apply(clean_text)
test_df['clean_review'] = test_df['review'].apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/youssef/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Prepare the Data for Model Input

# %%
batch_size = 32

train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True
)

test_dataloader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False
)

# %% [markdown]
# # Distribution of Sentiments

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of sentiments
sns.countplot(x='sentiment', data=train_df)
plt.title('Distribution of Sentiments')
plt.xlabel('Sentiment (0 = Negative, 1 = Positive)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Review Length Distribution

# %%
# Review length distribution
train_df['review_length'] = train_df['review'].apply(len)

plt.figure(figsize=(10, 6))
sns.histplot(train_df['review_length'], bins=50, kde=True)
plt.title('Review Length Distribution')
plt.xlabel('Review Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Word Clouds

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/ac/66/937d1d73389c0b501c928c4d8513653063d2b40272dff70d0e283d8b9144/wordcloud-1.9.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading wordcloud-1.9.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in /Users/youssef/anaconda3/lib/python3.11/site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in /Users/youssef/anaconda3/lib/python3.11/site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-macosx_11_0_arm64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 137.4 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
from wordcloud import WordCloud

# Generate word cloud for positive reviews
positive_reviews = ' '.join(train_df[train_df['sentiment'] == 1]['review'])
wordcloud_positive = WordCloud(width=800, height=400, background_color='white').generate(positive_reviews)

# Generate word cloud for negative reviews
negative_reviews = ' '.join(train_df[train_df['sentiment'] == 0]['review'])
wordcloud_negative = WordCloud(width=800, height=400, background_color='black', colormap='Blues').generate(negative_reviews)

# Plot word clouds
plt.figure(figsize=(14, 7))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_positive, interpolation='bilinear')
plt.title('Positive Reviews Word Cloud')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(wordcloud_negative, interpolation='bilinear')
plt.title('Negative Reviews Word Cloud')
plt.axis('off')

plt.show()

# %% [markdown]
# # Feature Engineering: Automated Feature Extraction and Selection

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# Extract features such as text length, word count, and TF-IDF vectors.

# %%
# Feature extraction: Text length and word count
train_df['text_length'] = train_df['clean_review'].apply(len)
train_df['word_count'] = train_df['clean_review'].apply(lambda x: len(x.split()))

test_df['text_length'] = test_df['clean_review'].apply(len)
test_df['word_count'] = test_df['clean_review'].apply(lambda x: len(x.split()))

# %% [markdown]
# # TF-IDF Vectors

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# TF-IDF Vectorization
tfidf = TfidfVectorizer(max_features=5000)

train_tfidf = tfidf.fit_transform(train_df['clean_review'])
test_tfidf = tfidf.transform(test_df['clean_review'])

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import mutual_info_classif

# Feature selection using mutual information
mi = mutual_info_classif(train_tfidf, train_df['sentiment'], discrete_features=True)
mi_scores = pd.Series(mi, index=tfidf.get_feature_names_out()).sort_values(ascending=False)

# Select top features based on mutual information score
top_features = mi_scores.head(20).index.tolist()
print(top_features)
# Out:
# /Users/youssef/anaconda3/lib/python3.11/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# /Users/youssef/anaconda3/lib/python3.11/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# /Users/youssef/anaconda3/lib/python3.11/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# /Users/youssef/anaconda3/lib/python3.11/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# /Users
site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# /Users/youssef/anaconda3/lib/python3.11/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# /Users/youssef/anaconda3/lib/python3.11/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# /Users/youssef/anaconda3/lib/python3.11/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# /Users/youssef/anaconda3/lib/python3.11/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# /Users/youssef/anaconda3/lib/python3.11/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# /Users/youssef/anaconda3/lib/python3.11/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Combining Features into a DataFrame

# %%
import numpy as np

# Combine features into a DataFrame
train_features = pd.DataFrame(train_tfidf.toarray(), columns=tfidf.get_feature_names_out())
train_features['text_length'] = train_df['text_length']
train_features['word_count'] = train_df['word_count']

test_features = pd.DataFrame(test_tfidf.toarray(), columns=tfidf.get_feature_names_out())
test_features['text_length'] = test_df['text_length']
test_features['word_count'] = test_df['word_count']

# %% [markdown]
# # Final Model Training

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Split data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(train_features, train_df['sentiment'], test_size=0.2, random_state=42)

# Train a logistic regression model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Evaluate the model
y_pred = model.predict(X_val)
accuracy = accuracy_score(y_val, y_pred)
print(f'Validation Accuracy: {accuracy}')
print(classification_report(y_val, y_pred))
# Out:
# Validation Accuracy: 0.875
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87      2485
#            1       0.86      0.89      0.88      2515
#
#     accuracy                           0.88      5000
#    macro avg       0.88      0.87      0.87      5000
# weighted avg       0.88      0.88      0.87      5000

# %% [markdown]
# # Model Integration

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /Users/youssef/anaconda3/lib/python3.11/site-packages (4.32.1)
# Requirement already satisfied: filelock in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /Users/youssef/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/youssef/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2024.2.2)

# %%
from transformers import BertForSequenceClassification, AdamW, BertTokenizer

# Load the BERT model and tokenizer
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # Prepare Data for BERT

# %%
import torch
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset

# Tokenize and encode the data
def encode_data(text_list, tokenizer, max_length=128):
    input_ids = []
    attention_masks = []

    for text in text_list:
        encoded = tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=max_length,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
        )
        input_ids.append(encoded['input_ids'])
        attention_masks.append(encoded['attention_mask'])

    input_ids = torch.cat(input_ids, dim=0)
    attention_masks = torch.cat(attention_masks, dim=0)

    return input_ids, attention_masks

train_input_ids, train_attention_masks = encode_data(train_df['review'].tolist(), tokenizer)
test_input_ids, test_attention_masks = encode_data(test_df['review'].tolist(), tokenizer)

train_labels = torch.tensor(train_df['sentiment'].values)
test_labels = torch.tensor(test_df['sentiment'].values)

train_dataset = TensorDataset(train_input_ids, train_attention_masks, train_labels)
test_dataset = TensorDataset(test_input_ids, test_attention_masks, test_labels)

train_dataloader = DataLoader(train_dataset, sampler=RandomSampler(train_dataset), batch_size=32)
test_dataloader = DataLoader(test_dataset, sampler=SequentialSampler(test_dataset), batch_size=32)

# %% [markdown]
# # Fine-tune the BERT Model

# %%
from transformers import get_linear_schedule_with_warmup

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

optimizer = AdamW(model.parameters(), lr=2e-5, eps=1e-8)
total_steps = len(train_dataloader) * 3  # 3 epochs
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)

for epoch in range(3):
    model.train()
    total_loss = 0

    for batch in train_dataloader:
        b_input_ids, b_input_mask, b_labels = tuple(t.to(device) for t in batch)
        model.zero_grad()

        outputs = model(b_input_ids, attention_mask=b_input_mask, labels=b_labels)
        loss = outputs.loss
        total_loss += loss.item()

        loss.backward()
        optimizer.step()
        scheduler.step()

    avg_train_loss = total_loss / len(train_dataloader)
    print(f'Epoch {epoch + 1}, Loss: {avg_train_loss}')

# %% [markdown]
# # Evaluate the Model

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

model.eval()
predictions, true_labels = [], []

for batch in test_dataloader:
    b_input_ids, b_input_mask, b_labels = tuple(t.to(device) for t in batch)

    with torch.no_grad():
        outputs = model(b_input_ids, attention_mask=b_input_mask)

    logits = outputs.logits
    predictions.append(logits.argmax(dim=-1).cpu().numpy())
    true_labels.append(b_labels.cpu().numpy())

predictions = np.concatenate(predictions)
true_labels = np.concatenate(true_labels)

accuracy = accuracy_score(true_labels, predictions)
precision, recall, f1, _ = precision_recall_fscore_support(true_labels, predictions, average='binary')

print(f'Test Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')

# %% [markdown]
# # Save the Model and Tokenizer

# %%
import os
from transformers import BertForSequenceClassification, BertTokenizer

# Define the model save path
model_save_path = './model_save/'

# Create the directory if it doesn't exist
if not os.path.exists(model_save_path):
    os.makedirs(model_save_path)

# Save the fine-tuned model and tokenizer
model.save_pretrained(model_save_path)
tokenizer.save_pretrained(model_save_path)

print(f'Model and tokenizer saved to {model_save_path}')
